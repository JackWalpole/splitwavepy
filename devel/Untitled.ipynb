# %%
# %matplotlib notebook
import splitwavepy as sw
import matplotlib.pyplot as plt
import numpy as np

# %%
# from explore_splitting import plot
# plot()

# %%
line1 = plt.plot(np.arange(10))
line2 = plt.plot(np.arange(10)+3)
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
line1[0].set_data(np.arange(10),np.arange(10)*2)

# %%
plt.show()
