# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append("..")
import splitwavepy as sw

import numpy as np
import matplotlib.pyplot as plt

# %%
a = sw.EigenM(fast=45,lag=1.5,delta=0.02,noise=0.05)

# %%
a.plot()

# %%
# Error analysis
fig,ax = plt.subplots(2)
ax0 = plt.subplot(121)
ax1 = plt.subplot(122)

ax0.plot(a.degs[0,:],a.fastprofile())
ax0.axvline(a.fast)
ax0.axvline(a.fast-2*a.dfast,alpha=0.5)
ax0.axvline(a.fast+2*a.dfast,alpha=0.5)
ax0.set_title('fast direction')

ax1.plot(a.lags[:,0],a.lagprofile())
ax1.axvline(a.lag)
ax1.axvline(a.lag-2*a.dlag,alpha=0.5)
ax1.axvline(a.lag+2*a.dlag,alpha=0.5)
ax1.set_title('lag time')

plt.show()

# %%
pr = sw.Pair(fast=45,lag=1.5,delta=0.05,noise=0.001)
bs = sw.eigval.Bootstrap(pr,nits=10)

# %%
# Error analysis
fig,ax = plt.subplots(2)
ax0 = plt.subplot(121)
ax1 = plt.subplot(122)

for a in bs.listM:
    ax0.plot(a.degs[0,:],a.fastprofile())
    ax1.plot(a.lags[:,0],a.lagprofile())
    
# ax0.axvline(a.fast)
# ax0.axvline(a.fast-2*a.dfast,alpha=0.5)
# ax0.axvline(a.fast+2*a.dfast,alpha=0.5)
ax0.set_title('fast direction')

# ax1.axvline(a.lag)
# ax1.axvline(a.lag-2*a.dlag,alpha=0.5)
# ax1.axvline(a.lag+2*a.dlag,alpha=0.5)
ax1.set_title('lag time')

plt.show()
