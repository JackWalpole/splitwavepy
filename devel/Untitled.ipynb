# %%
# %matplotlib notebook
import splitwavepy as sw
import matplotlib.pyplot as plt
import numpy as np

# %%
# from explore_splitting import plot
# plot()

# %%
line1 = plt.plot(np.arange(10))
line2 = plt.plot(np.arange(10)+3)
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
line1[0].set_data(np.arange(10),np.arange(10)*2)

# %%
plt.show()

# %%
a = sw.Data().Split()
# Out:
#     SCfast   SCdfast     SClag    SCdlag    XCfast   XCdfast     XClag    XCdlag         Q        SI
#       0.00      0.00      8.30      0.00     45.00      0.00      0.00      0.00     -1.00     -0.00

# %%
ll,dd = a._grid
C = plt.contourf(ll, dd, a.sc.vals)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for coll in C.collections: 
    plt.gca().collections.remove(coll) 
C = plt.contourf(ll,dd, a.sc.lam2) 
plt.draw()

# %%
bs = plt.imshow(a.sc.vals.T, extent=[0,8.2,0,180], aspect="auto")
# plt.set_aspect(3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bs.set_array(a.sc.vals)
