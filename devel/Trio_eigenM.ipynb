# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append("..")
import splitwavepy as sw

import numpy as np
import matplotlib.pyplot as plt

# %%
a = sw.Trio(split=(30,1.2),ray=(0,45),delta=0.05)
a.plot()

# %%
a.rotate2ray()
a.plot()

# %%
a.rayvecs
# Out:
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
a.set_ray()

# %%
a.rotate2ray()

# %%
a.rayvecs
# Out:
# array([[-0.04602608, -0.14782336,  0.98794223],
#        [ 0.36154168,  0.91947878,  0.15442278],
#        [-0.93121921,  0.36428977,  0.01112431]])

# %%
np.allclose(np.eye(3),[[1,0,0],[0,1,0],[0,0,1]])
# Out:
# True

# %%
a.plot()
