# %%
# %load_ext autoreload
# %autoreload 2

import splitwavepy as sw
import numpy as np
import pandas as pd
import obspy as obs
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = sw.synth(split=((30, 1.2)), noise=0.05)
a.report()
a.plot()
# Out:
#       fast     dfast       lag      dlag         Q        SI
#      41.00     24.50      0.80      0.50      0.34     -6.93

# %%
ms = [ sw.synth(split=(30, 1.2), noise = 0.5) for _ in range(2500) ]

# %%
plt.imshow(np.stack([ m.likelihood for m in ms ]).sum(axis=0))
plt.show()

# %%
m = sw.synth(split=(20,10), noise=0.005, pol=0)
polscan = np.asarray([ m.splitting_intensity(pol=pol) for pol in np.arange(180) ])
plt.plot(polscan)
plt.show()
np.argmax(abs(polscan)) - 90
# Out:
# 15

# %%
m.silver_chan()
# Out:
# (28.0, 8.0, 4.4000000000000004, 0.85000000000000009)

# %%
m.plot()

# %%
sw.Group??

# %%
g = sw.synthmany(5)

# %%
g.plot()

# %%
sw.Group??
