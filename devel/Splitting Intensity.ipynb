# %%
# %load_ext autoreload
# %autoreload 2

import splitwavepy as sw
import numpy as np
import pandas as pd
import obspy as obs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = sw.synth(split=((30, 1.2)), noise=0.005)
a.report()
a.plot()
# Out:
#       fast     dfast       lag      dlag         Q        SI
#      26.00      4.00      1.30      0.15      1.00   0.00000

# %%
ms = [ sw.synth(split=(30, 1.2), noise = 0.5) for _ in range(2500) ]

# %%
plt.imshow(np.stack([ m.likelihood for m in ms ]).sum(axis=0))
plt.show()
