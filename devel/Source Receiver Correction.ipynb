# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append("..")
import splitwavepy as sw

import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = sw.EigenM(delta=0.05,split=(30,1.2),srccorr=(30,1.2))
a.plot()

# %%
a.data.plot()

# %%
a.data.unsplit(30,1.2)

# %%
a.data.plot()
