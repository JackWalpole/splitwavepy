# %%
# %load_ext autoreload
# %autoreload 2

# %%
import splitwavepy as sw
import numpy as np
import matplotlib.pyplot as plt

# %%
a = sw.synth(split=(50,1.2), noise=0.03)

# %%
a.plot()

# %%
def synthmany(n, **kwargs):
    return sw.Group([ sw.synth(**kwargs) for x in range(n) ])

# %%
g = synthmany(100, split=(25,1.2), noise=0.05)
g.plot()

# %%
plt.imshow(g.likelihood)
plt.show()

# %%
g.plot()
# Out:
# /Users/glyjw/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
g.likelihood.min()
# Out:
# 0.14343990203619855

# %%
l = m / m.max()

# %%
l.shape
# Out:
# (83, 180)

# %%
        idx = core.max_idx(vals)
        ll, dd = self._grid
