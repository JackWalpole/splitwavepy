# %%
# %load_ext autoreload
# %autoreload 2
# import obspy as obs
# import splitwavepy as sw

# %%
d = '/Users/glyjw/Applications/splitwavepy/examples/CCM_SKS/'

st = obs.read(d + '*.SAC')
delta = st[0].stats.delta
x, y = st[1].data, st[0].data

# %%
a = sw.fromst(st)
a.plot()

# %%
a.window(39,47).plot()

# %%
b = a.windowscan(20,25,35,40)

# %%
plt.imshow(np.sum(b.stack, axis=0), aspect='auto')
plt.show()
