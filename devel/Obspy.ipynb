# %%
d = '/Users/glyjw/Applications/splitwavepy/examples/CCM_SKS/'

st = obs.read(d + '*.SAC')
delta = st[0].stats.delta
x, y = st[1].data, st[0].data

# %%
a = sw.fromst(st)
a.plot()

# %%
a.window(39,47).plot()

# %%
b = a.scanwindow(20,25,35,40)

# %%
b.plot()

# %%
# Analysis of NEW
srcdir = '/Users/glyjw/Joseph/NEW/'
a = sw.fromsac(srcdir + 'NEW_2002256_222829_BH?.sac')
a.plot()

# %%
st = obs.read(srcdir + 'NEW_2002256_222829_BH?.sac')

# %%
st[0].stats
# Out:
#          network: US
#          station: NEW
#         location:
#          channel: BHE
#        starttime: 2002-09-13T22:28:29.016000Z
#          endtime: 2002-09-13T23:18:28.991000Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 120000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'nzjday': 256, 'depmin': -901.0, 'b': 0.0, 'az': 21.3226, 'knetwk': 'US', 'kstnm': 'NEW', 'delta': 0.025, 'stla': 48.26, 'npts': 120000, 'gcarc': 113.2626, 'baz': 327.914, 'lovrok': 1, 'evdp': 21.0, 'depmen': -163.98067, 'lcalda': 0, 'lpspol': 1, 'stlo': -117.12, 'leven': 1, 'iztype': 9, 'nzmin': 28, 'e': 2999.975, 'dist': 12591.242, 'nzyear': 2002, 'nvhdr': 6, 'iftype': 1, 'scale': 1.0, 'nzhour': 22, 'nzmsec': 16, 'evlo': 93.07, 'kcmpnm': 'BHE', 'evla': 13.04, 'nzsec': 29, 'depmax': 626.0})

# %%
from obspy.taup import TauPyModel
model = TauPyModel('iasp91')
# timing
arrivals = model.get_travel_times_geo(a.evdp, a.evla, a.evlo, a.stla, a.stlo, phase_list=['SKS'])
skstime = st[0].stats.starttime + arrivals[0].time

# %%
skstime
# Out:
# 2000-08-15T05:18:42.734818Z

# %%
skstime + a.data._t0
# Out:
# 2000-08-15T05:18:42.734818Z

# %%
np.allclose(c.listM[0].data.x == c.listM[1].data.
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
np.allclose(c.listM[0].data.data, c.listM[1].data.data)
# Out:
# True

# %%
c.plot()

# %%
sw.synth().plot()

# %%
from obspy import UTCDateTime

# %%
UTCDateTime?
