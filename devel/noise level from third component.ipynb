# %%
# %load_ext autoreload
# %autoreload 2

import splitwavepy as sw
import obspy as obs
import matplotlib.pyplot as plt
import numpy as np

# %%
d = sw.Data(split=(30,1.2))
d.plot()
d.unsplit(30,1.2).plot()

# %%
f = '../examples/CCM_SKS/*.SAC'
st = obs.read(f)
st.plot()

# %%
m = sw.funcs.read(f)
m.plot()

# %%
x, y, z = [ tr.data for tr in st.traces ]

# %%
t = np.arange(len(x))
[ plt.plot(i) for i in [ x, y, z ] ]
plt.show()

# %%
m.data.plot()

# %%
m.data_corr(m.fast, m.lag).chop().plot()

# %%
xx, yy, zz = [ comp[m.data._w0(): m.data._w1()] for comp in [x, y, z] ] 

t = np.arange(len(xx))
[ plt.plot(i) for i in [ xx, yy, zz ] ]
plt.show()

# %%
dc = m.data_corr(m.fast, m.lag)
cx, cy = dc._chopxy()
cz = z[dc._w0() : dc._w1()]
t = np.arange(len(xx))
[ plt.plot(i) for i in [ xx, cy, cz ] ]
plt.show()

# %%
print(m.fast, m.lag)
m.data.split(60, 2.3).x - m.data.x
# Out:
# 15.0 0.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2c76e3274ad7> in <module>()
#       1 print(m.fast, m.lag)
# ----> 2 m.data.split(60, 2.3).x - m.data.x
#
# ValueError: operands could not be broadcast together with shapes (1155,) (1201,)

# %%
m.data.split(30,4).plot()

# %%
sw.core.chop??
#m.data.wbeg(), m.data.wend()

# %%
m.data.plot()

# %%
m.data.split(3,3).plot()

# %%
synth = sw.synth(fast=30, split=1.2)
synth.data.plot()

# %%
sw.synth(fast=30, lag=1.2).plot()

# %%
m.data.unsplit(30,1.2)
# Out:
# shit balls
# [autoreload of splitwavepy.core.data failed: Traceback (most recent call last):
#   File "/Users/jackwalpole/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/jackwalpole/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 385, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/jackwalpole/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 324, in update_generic
#     update(a, b)
#   File "/Users/jackwalpole/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 289, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/jackwalpole/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 324, in update_generic
#     update(a, b)
# ...
