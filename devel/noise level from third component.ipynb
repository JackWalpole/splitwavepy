# %%
import splitwavepy as sw
import obspy as obs
import matplotlib.pyplot as plt
import numpy as np

# %%
f = '../examples/CCM_SKS/*.SAC'
st = obs.read(f)
st.plot()

# %%
m = sw.funcs.read(f)
m.plot()

# %%
x, y, z = [ tr.data for tr in st.traces ]

# %%
t = np.arange(len(x))
[ plt.plot(i) for i in [ x, y, z ] ]
plt.show()

# %%
m.data.plot()
