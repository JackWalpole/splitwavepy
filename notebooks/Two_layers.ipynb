# %%
import splitwavepy as sw
import matplotlib.pyplot as plt
import numpy as np

# %%
a = sw.Data(delta=0.1, split=[(30,1.2),(90,1.3),(140,0.5),(40,1.3)], noise=0.02)
a.plot()

# %%
b = a.EigenM()
b.plot()

# %%
b.data_corr().EigenM().plot()

# %%
fig, ax = plt.subplots()
b._psurf(ax, vals=b.lam1/b.lam2)
plt.show()

# %%
a = sw.Data(delta=0.1, split=(46,1.5), noise=0.01)
b = a.EigenM(lags=(8,))
# b = a.XcorrM()

sublags = b.lags[0:-1:int(b.lags.size/6)]
subdegs = b.degs[0:-1:int(b.degs.size/6)]
sublags = sublags + (b.lags[-1]-sublags[-1]) / 2
subdegs = subdegs + (b.degs[-1]-subdegs[-1]) / 2

fig, ax = plt.subplots()



b._psurf(ax, vals=b.lam1/b.lam2)
# b._psurf(ax, vals=b.xc)

lagtot = b.lags[-1] - b.lags[0]
degtot = b.degs[-1] - b.degs[0]
boost = 15 * lagtot / np.max((x**2 + y**2)**.5)
# boost=200
for fast in subdegs:
    for lag in sublags:
        x, y = b.data.unsplit(fast, lag).chopdata()
        ax.plot(lag + y*boost/degtot, fast + x*boost/lagtot, color='w',alpha=0.5)
        
# b.data.unsplit(30,1.2)._ppm(ax)
# ax.set_frame_on(False)
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)
# ax.scatter(0,0)
plt.show()

# %%
90 / np.max((x**2 + y**2)**.5)
# Out:
# 630.66872277871073

# %%
b.lags[-1]
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2.2,
#         2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,  4.4,
#         4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.4,  6.6,  6.8,
#         7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2])
