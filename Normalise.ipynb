# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import signal

# the splitting routines
import splitting as s

# %%
def plt_pair(pair):
    from matplotlib import gridspec
    fig = plt.figure(figsize=(12, 6)) 
    gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1]) 
    ax0 = plt.subplot(gs[0])
    ax0.plot(pair.T)
    ax1 = plt.subplot(gs[1])
    ax1.plot(pair[0,:],pair[1,:])
    plt.axis('equal')
    plt.show()
    
def plt_surf(surf):
    from matplotlib import colors, ticker, cm
    plt.contourf(lag,deg,l2/(l1+l2),locator=ticker.LogLocator(),cmap='viridis_r')

# %%
# synthetic data
ricker = signal.ricker(500, 16.0)
pair = np.vstack((ricker,np.zeros(ricker.shape)))
noise = np.random.normal(0,.005,pair.shape)
splitdata = s.split(pair+noise,110,10)

# %%
plt_pair(splitdata)

# %%
deg, lag, l1, l2 = s.grideigcov(splitdata,30)

# %%
from matplotlib import colors, ticker, cm
plt.contourf(lag,deg,l2/(l1+l2),locator=ticker.LogLocator(),cmap='viridis_r')
